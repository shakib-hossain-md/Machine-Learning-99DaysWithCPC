# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv('/content/IndFD-PM-DT dataset.csv')

# %%
dataset.head()
# Out:
#               Datetime  Vibration_Level  Temperature_Readings  Pressure_Data  \
# 0  2021-06-21 08:00:00         0.336129             23.865396      15.346143
# 1  2019-03-07 10:00:00         0.441680             27.332215      19.648924
# 2  2023-01-13 08:00:00         0.349080             29.483668      10.466149
# 3  2021-08-13 23:00:00         0.507108             19.005118      32.012730
# 4  2022-09-21 07:00:00         1.402247             32.096101      22.620923
#
#    Acoustic_Signals  Humidity_Levels  Motor_Speed  Torque_Data  \
# 0         42.709897        31.404880    59.812632     3.677243
# 1         56.146535        23.516423    65.572156     1.057276
# 2         80.487979        27.537668    53.951904     0.881063
# 3         63.602072        14.888160    36.715289     1.372567
# 4         47.574150        22.703902    52.411045     0.437824
#
#    Energy_Consumption  Production_Rate  ...  Controller_Setpoints  \
# ...

# %%
dataset.describe().transpose()
# Out:
#                                  count        mean        std        min  \
# Vibration_Level                43825.0    0.499235   0.499789   0.000003
# Temperature_Readings           43825.0   30.013493   5.003203  10.277032
# Pressure_Data                  43825.0   28.468127  15.879884   0.216250
# Acoustic_Signals               43825.0   49.818038  14.957175 -11.435987
# Humidity_Levels                43825.0   20.170006  12.173021   0.079138
# Motor_Speed                    43825.0   49.909403   9.966962   1.705640
# Torque_Data                    43825.0    3.003601   2.124429   0.006696
# Energy_Consumption             43825.0    9.957493   9.983611   0.000449
# Production_Rate                43825.0  100.073372  25.000217  -4.730857
# Tool_Wear_Rate                 43825.0   24.995389  14.382023   0.058636
# Machine_Utilization_Rate       43825.0   66.797345  17.805740   3.761270
# Cycle_Time_Per_Operation       43825.0    1.998885   0.497685  -0.022744
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43825 entries, 0 to 43824
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Datetime                       43825 non-null  object
#  1   Vibration_Level                43825 non-null  float64
#  2   Temperature_Readings           43825 non-null  float64
#  3   Pressure_Data                  43825 non-null  float64
#  4   Acoustic_Signals               43825 non-null  float64
#  5   Humidity_Levels                43825 non-null  float64
#  6   Motor_Speed                    43825 non-null  float64
#  7   Torque_Data                    43825 non-null  float64
#  8   Energy_Consumption             43825 non-null  float64
#  9   Production_Rate                43825 non-null  float64
#  10  Tool_Wear_Rate                 43825 non-null  float64
#  11  Machine_Utilization_Rate       43825 non-null  float64
# ...

# %%
dataset.isnull().sum()
# Out:
# Datetime                         0
# Vibration_Level                  0
# Temperature_Readings             0
# Pressure_Data                    0
# Acoustic_Signals                 0
# Humidity_Levels                  0
# Motor_Speed                      0
# Torque_Data                      0
# Energy_Consumption               0
# Production_Rate                  0
# Tool_Wear_Rate                   0
# Machine_Utilization_Rate         0
# Cycle_Time_Per_Operation         0
# Idle_Time                        0
# Machine_Load_Percentage          0
# Ambient_Temperature              0
# Humidity                         0
# Air_Quality_Index                0
# Machine_Health_Index             0
# Failure_Mode_Indicators          0
# Maintenance_Logs                 0
# Previous_Fault_Occurrences       0
# Predictive_Maintenance_Scores    0
# Component_Degradation_Index      0
# Real_Time_Performance_Index      0
# Machine_Start_Stop_Events        0
# Downtime_Incidents               0
# ...

# %%
dataset['Datetime'] = pd.to_datetime(dataset['Datetime'])

# %%
#dataset['timestamp'] = dataset['Datetime'].astype(int) // 10**9

# %%
dataset['Datetime']
# Out:
# 0       2021-06-21 08:00:00
# 1       2019-03-07 10:00:00
# 2       2023-01-13 08:00:00
# 3       2021-08-13 23:00:00
# 4       2022-09-21 07:00:00
#                 ...
# 43820   2019-09-19 01:00:00
# 43821   2020-04-15 04:00:00
# 43822   2023-05-09 22:00:00
# 43823   2019-02-05 20:00:00
# 43824   2020-10-20 03:00:00
# Name: Datetime, Length: 43825, dtype: datetime64[ns]

# %%
# dataset['timestamp']

# %%
corr = dataset.corr()
plt.figure(figsize=(30, 30))
sns.heatmap(corr, annot=True, linewidths=2, cmap='viridis')
plt.tight_layout()

# %%
corr.sort_index(ascending=True)
# Out:
#                                Datetime  Vibration_Level  \
# Acoustic_Signals               0.001394         0.003042
# Actual_vs_Setpoint_Values     -0.002488         0.007500
# Air_Quality_Index             -0.000220         0.006336
# Alarm_Trigger_Data            -0.001413        -0.001872
# Ambient_Temperature           -0.010303         0.003630
# Anomaly_Scores                -0.002075         0.004442
# Component_Degradation_Index   -0.003062         0.003278
# Controller_Setpoints          -0.001760         0.007167
# Cycle_Time_Per_Operation       0.004123         0.006355
# Datetime                       1.000000         0.002722
# Downtime_Incidents             0.011280        -0.002777
# Energy_Consumption             0.002581         0.001433
# Failure_Mode_Indicators        0.001095         0.007001
# Fault_Diagnosis               -0.004255         0.004320
# Fault_Probability             -0.003642         0.006381
# ...

# %%
corr['Fault_Diagnosis'].sort_values(ascending=True)
# Out:
# Repair_Logs                     -0.010141
# Production_Rate                 -0.008337
# Downtime_Incidents              -0.005901
# Air_Quality_Index               -0.005382
# Operator_Shift_Data             -0.005353
# Machine_Health_Index            -0.005174
# Datetime                        -0.004255
# Cycle_Time_Per_Operation        -0.003394
# Idle_Time                       -0.002917
# Component_Degradation_Index     -0.002823
# Temperature_Readings            -0.002334
# Failure_Mode_Indicators         -0.002089
# Humidity_Levels                 -0.001440
# Machine_Start_Stop_Events       -0.001343
# Torque_Data                     -0.000621
# Motor_Speed                     -0.000612
# Maintenance_Logs                -0.000591
# Quality_Control_Test_Results    -0.000543
# Machine_Utilization_Rate        -0.000373
# Tool_Wear_Rate                  -0.000145
# Machine_Load_Percentage          0.000199
# Spare_Part_Usage                 0.000209
# ...

# %%
 df_numeric = dataset.drop(columns=['Datetime'])

# %%
correlation_matrix = df_numeric.corr()

# %%
correlation_pairs = correlation_matrix.unstack()

# %%
correlation_pairs = correlation_pairs[correlation_pairs != 1]

# %%
sorted_correlation_pairs = correlation_pairs.abs().sort_values(ascending=False)

# %%
strongest_correlations = sorted_correlation_pairs.head(10)

# %%
print(strongest_correlations)
# Out:
# Controller_Setpoints           Actual_vs_Setpoint_Values        0.928094
# Actual_vs_Setpoint_Values      Controller_Setpoints             0.928094
# Tool_Wear_Rate                 Predictive_Maintenance_Scores    0.014846
# Predictive_Maintenance_Scores  Tool_Wear_Rate                   0.014846
# Pressure_Data                  Machine_Load_Percentage          0.013688
# Machine_Load_Percentage        Pressure_Data                    0.013688
# Quality_Control_Test_Results   Alarm_Trigger_Data               0.013204
# Alarm_Trigger_Data             Quality_Control_Test_Results     0.013204
# Ambient_Temperature            Pressure_Data                    0.012736
# Pressure_Data                  Ambient_Temperature              0.012736
# dtype: float64

# %%
plt.scatter(dataset['Controller_Setpoints'], dataset['Actual_vs_Setpoint_Values'])
plt.title('Scatter Plot between Controller Setpoints and Actual vs Setpoint Values')
plt.xlabel('Controller_Setpoints')
plt.ylabel('Actual_vs_Setpoint_Values')
plt.show()

# %%
plt.scatter(dataset['Controller_Setpoints'], dataset['Actual_vs_Setpoint_Values'], c=dataset['Fault_Diagnosis'])
plt.title('Scatter Plot between Controller Setpoints and Actual vs Setpoint Values')
plt.xlabel('Controller_Setpoints')
plt.ylabel('Actual_vs_Setpoint_Values')
plt.colorbar(label='Fault Diagnosis')
plt.show()

# %%
plt.scatter(dataset['Tool_Wear_Rate'], dataset['Predictive_Maintenance_Scores'])
plt.title('Scatter Plot between Tool_Wear_Rate and Predictive_Maintenance_Scores')
plt.xlabel('Tool_Wear_Rate')
plt.ylabel('Predictive_Maintenance_Scores')
plt.show()

# %%
plt.scatter(dataset['Tool_Wear_Rate'], dataset['Predictive_Maintenance_Scores'], c=dataset['Fault_Diagnosis'])
plt.title('Scatter Plot between Tool_Wear_Rate and Predictive_Maintenance_Scores')
plt.xlabel('Tool_Wear_Rate')
plt.ylabel('Predictive_Maintenance_Scores')
plt.colorbar(label='Fault Diagnosis')
plt.show()

# %%
plt.scatter(dataset['Machine_Load_Percentage'], dataset['Pressure_Data'])
plt.title('Scatter Plot between Machine_Load_Percentage and Pressure_Data')
plt.xlabel('Machine_Load_Percentage')
plt.ylabel('Pressure_Data')
plt.show()

# %%
plt.scatter(dataset['Ambient_Temperature'], dataset['Pressure_Data'])
plt.title('Scatter Plot between Ambient_Temperature and Pressure_Data')
plt.xlabel('Ambient_Temperature')
plt.ylabel('Pressure_Data')
plt.show()

# %%
dataset['Fault_Diagnosis'].value_counts()
# Out:
# Fault_Diagnosis
# 0    30531
# 1     4470
# 2     4406
# 4     2229
# 3     2189
# Name: count, dtype: int64

# %%
dataset['Fault_Diagnosis'].value_counts().plot()
# Out:
# <Axes: xlabel='Fault_Diagnosis'>

# %%
sns.countplot(x=dataset['Fault_Diagnosis'], palette='bright')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7340\3150153748.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=dataset['Fault_Diagnosis'], palette='bright')
# <Axes: xlabel='Fault_Diagnosis', ylabel='count'>

# %%
dataset['Alarm_Trigger_Data'].value_counts()
# Out:
# Alarm_Trigger_Data
# 0    41651
# 1     2174
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x=dataset['Alarm_Trigger_Data'], hue=dataset['Fault_Diagnosis'], palette='bright')
# Out:
# <Axes: xlabel='Alarm_Trigger_Data', ylabel='count'>

# %%
dataset['Anomaly_Scores']
# Out:
# 0        31.806763
# 1        16.828544
# 2        30.532711
# 3         2.718529
# 4        35.209996
#            ...
# 43820    12.286389
# 43821    20.070351
# 43822    13.628070
# 43823     9.445317
# 43824     6.441258
# Name: Anomaly_Scores, Length: 43825, dtype: float64

# %%
sns.scatterplot(x=dataset.index, y=dataset['Anomaly_Scores'], hue=dataset['Fault_Diagnosis'], palette='viridis')
plt.title('Anomaly Scores with Hue based on Fault Diagnosis')
plt.xlabel('Index')
plt.ylabel('Anomaly Scores')
plt.show()

# %%
plt.scatter(dataset.index, dataset['Anomaly_Scores'], c=dataset['Anomaly_Scores'], cmap='viridis')
plt.title('Anomaly Scores with Continuous Hue')
plt.xlabel('Index')
plt.ylabel('Anomaly Scores')
plt.colorbar(label='Anomaly Scores')
plt.show()

# %%
dataset['Acoustic_Signals'].plot()
# Out:
# <Axes: >

# %%
dataset['Energy_Consumption'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Energy_Consumption'], y=dataset['Fault_Diagnosis'])
plt.title('Energy_Consumption and Fault Diagnosis')
plt.xlabel('Energy_Consumption')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
dataset['Pressure_Data'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Pressure_Data'], y=dataset['Fault_Diagnosis'])
plt.title('Pressure Data and Fault Diagnosis')
plt.xlabel('Pressure_Data')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
max_value = dataset['Pressure_Data'].max()
max_value
# Out:
# np.float64(91.92969686902586)

# %%
dataset['Previous_Fault_Occurrences']
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 43820    0
# 43821    0
# 43822    0
# 43823    0
# 43824    0
# Name: Previous_Fault_Occurrences, Length: 43825, dtype: int64

# %%
dataset['Previous_Fault_Occurrences'].value_counts()
# Out:
# Previous_Fault_Occurrences
# 0    37247
# 1     6578
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x=dataset['Previous_Fault_Occurrences'], hue=dataset['Fault_Diagnosis'], palette='bright')
# Out:
# <Axes: xlabel='Previous_Fault_Occurrences', ylabel='count'>

# %%
dataset['Production_Rate']
# Out:
# 0         71.472236
# 1         79.280461
# 2        100.994780
# 3        108.291454
# 4         95.616224
#             ...
# 43820    148.029482
# 43821     86.109704
# 43822    104.457433
# 43823    146.353829
# 43824     73.338522
# Name: Production_Rate, Length: 43825, dtype: float64

# %%
dataset['Production_Rate'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Production_Rate'], y=dataset['Fault_Diagnosis'])
plt.title('Production_Rate and Fault Diagnosis')
plt.xlabel('Production_Rate')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
max_value = dataset['Production_Rate'].max()
max_value
# Out:
# np.float64(213.1695973315068)

# %%
dataset['Humidity']
# Out:
# 0        10.120674
# 1        40.192417
# 2        50.411194
# 3        59.506915
# 4        30.847874
#            ...
# 43820    54.285586
# 43821    47.979428
# 43822    18.901830
# 43823    21.980019
# 43824    25.480408
# Name: Humidity, Length: 43825, dtype: float64

# %%
dataset['Humidity'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Humidity'], y=dataset['Fault_Diagnosis'])
plt.title('Humidity and Fault Diagnosis')
plt.xlabel('Humidity')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
dataset['Failure_Mode_Indicators']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 43820    0
# 43821    0
# 43822    0
# 43823    0
# 43824    0
# Name: Failure_Mode_Indicators, Length: 43825, dtype: int64

# %%
dataset['Failure_Mode_Indicators'].value_counts()
# Out:
# Failure_Mode_Indicators
# 0    41611
# 1     2214
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x=dataset['Failure_Mode_Indicators'], hue=dataset['Fault_Diagnosis'], palette='bright')
# Out:
# <Axes: xlabel='Failure_Mode_Indicators', ylabel='count'>

# %%
dataset['Temperature_Readings']
# Out:
# 0        23.865396
# 1        27.332215
# 2        29.483668
# 3        19.005118
# 4        32.096101
#            ...
# 43820    32.978580
# 43821    26.184765
# 43822    34.318023
# 43823    36.644425
# 43824    27.074058
# Name: Temperature_Readings, Length: 43825, dtype: float64

# %%
dataset['Temperature_Readings'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Temperature_Readings'], y=dataset['Fault_Diagnosis'])
plt.title('Temperature_Readings and Fault Diagnosis')
plt.xlabel('Temperature_Readings')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
dataset['Spare_Part_Usage']
# Out:
# 0        4.326138
# 1        3.006478
# 2        0.468073
# 3        3.270788
# 4        4.598529
#            ...
# 43820    1.645819
# 43821    1.675778
# 43822    4.841985
# 43823    1.790334
# 43824    3.374309
# Name: Spare_Part_Usage, Length: 43825, dtype: float64

# %%
dataset['Spare_Part_Usage'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Spare_Part_Usage'], y=dataset['Fault_Diagnosis'])
plt.title('Spare_Part_Usage and Fault Diagnosis')
plt.xlabel('Spare_Part_Usage')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
dataset['Air_Quality_Index']
# Out:
# 0        12.110422
# 1        16.954551
# 2        14.837031
# 3        10.806108
# 4        12.260189
#            ...
# 43820    36.331901
# 43821    34.095769
# 43822    70.645533
# 43823    15.229597
# 43824    53.402170
# Name: Air_Quality_Index, Length: 43825, dtype: float64

# %%
dataset['Air_Quality_Index'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x=dataset['Fault_Diagnosis'], y=dataset['Air_Quality_Index'])
plt.title('Fault_Diagnosis and Air_Quality_Index')
plt.xlabel('Fault_Diagnosis')
plt.ylabel('Air_Quality_Index')
plt.show()

# %%
dataset['Vibration_Level']
# Out:
# 0        0.336129
# 1        0.441680
# 2        0.349080
# 3        0.507108
# 4        1.402247
#            ...
# 43820    0.347451
# 43821    1.058969
# 43822    0.250290
# 43823    0.747001
# 43824    0.118154
# Name: Vibration_Level, Length: 43825, dtype: float64

# %%
dataset['Vibration_Level'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Vibration_Level'], y=dataset['Fault_Diagnosis'])
plt.title('Vibration_Level and Fault Diagnosis')
plt.xlabel('Vibration_Level')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
dataset['Quality_Control_Test_Results']
# Out:
# 0        89.347791
# 1        89.013490
# 2        86.990711
# 3        79.234826
# 4        86.246880
#            ...
# 43820    87.035059
# 43821    91.843367
# 43822    85.005856
# 43823    81.650147
# 43824    94.796409
# Name: Quality_Control_Test_Results, Length: 43825, dtype: float64

# %%
dataset['Quality_Control_Test_Results'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Quality_Control_Test_Results'], y=dataset['Fault_Diagnosis'])
plt.title('Quality_Control_Test_Results and Fault Diagnosis')
plt.xlabel('Quality_Control_Test_Results')
plt.ylabel('Fault Diagnosis')
plt.show()

# %%
dataset['Machine_Health_Index']
# Out:
# 0         87.438719
# 1         92.413396
# 2        100.157582
# 3         89.976769
# 4         91.404370
#             ...
# 43820     93.813279
# 43821     92.738270
# 43822     94.906257
# 43823     88.568237
# 43824     81.701677
# Name: Machine_Health_Index, Length: 43825, dtype: float64

# %%
dataset['Machine_Health_Index'].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=dataset['Machine_Health_Index'], y=dataset['Fault_Diagnosis'])
plt.title('Machine_Health_Index and Fault Diagnosis')
plt.xlabel('Machine_Health_Index')
plt.ylabel('Fault Diagnosis')
plt.show()

# %% [markdown]
# ## **Feature Selection**
#
# ---

# %%
dataset.head()
# Out:
#              Datetime  Vibration_Level  Temperature_Readings  Pressure_Data  \
# 0 2021-06-21 08:00:00         0.336129             23.865396      15.346143
# 1 2019-03-07 10:00:00         0.441680             27.332215      19.648924
# 2 2023-01-13 08:00:00         0.349080             29.483668      10.466149
# 3 2021-08-13 23:00:00         0.507108             19.005118      32.012730
# 4 2022-09-21 07:00:00         1.402247             32.096101      22.620923
#
#    Acoustic_Signals  Humidity_Levels  Motor_Speed  Torque_Data  \
# 0         42.709897        31.404880    59.812632     3.677243
# 1         56.146535        23.516423    65.572156     1.057276
# 2         80.487979        27.537668    53.951904     0.881063
# 3         63.602072        14.888160    36.715289     1.372567
# 4         47.574150        22.703902    52.411045     0.437824
#
#    Energy_Consumption  Production_Rate  ...  Controller_Setpoints  \
# ...

# %%
dataset.columns
# Out:
# Index(['Datetime', 'Vibration_Level', 'Temperature_Readings', 'Pressure_Data',
#        'Acoustic_Signals', 'Humidity_Levels', 'Motor_Speed', 'Torque_Data',
#        'Energy_Consumption', 'Production_Rate', 'Tool_Wear_Rate',
#        'Machine_Utilization_Rate', 'Cycle_Time_Per_Operation', 'Idle_Time',
#        'Machine_Load_Percentage', 'Ambient_Temperature', 'Humidity',
#        'Air_Quality_Index', 'Machine_Health_Index', 'Failure_Mode_Indicators',
#        'Maintenance_Logs', 'Previous_Fault_Occurrences',
#        'Predictive_Maintenance_Scores', 'Component_Degradation_Index',
#        'Real_Time_Performance_Index', 'Machine_Start_Stop_Events',
#        'Downtime_Incidents', 'Fault_Trigger_Timestamps',
#        'Controller_Setpoints', 'Actual_vs_Setpoint_Values',
#        'Alarm_Trigger_Data', 'Repair_Logs', 'Spare_Part_Usage',
#        'Anomaly_Scores', 'Fault_Probability', 'Operator_Shift_Data',
#        'Quality_Control_Test_Results', 'Fault_Diagnosis'],
# ...

# %%
numeric_df = dataset.select_dtypes(include=['float64', 'int64'])

# %%
correlation_with_target = numeric_df.corr()['Fault_Diagnosis'].sort_values(ascending=False)

# %%
print(correlation_with_target)
# Out:
# Fault_Diagnosis                  1.000000
# Alarm_Trigger_Data               0.010823
# Anomaly_Scores                   0.008682
# Acoustic_Signals                 0.008448
# Fault_Trigger_Timestamps         0.006720
# Energy_Consumption               0.006186
# Fault_Probability                0.005276
# Controller_Setpoints             0.005162
# Humidity                         0.005038
# Vibration_Level                  0.004320
# Predictive_Maintenance_Scores    0.004044
# Previous_Fault_Occurrences       0.002844
# Ambient_Temperature              0.002672
# Actual_vs_Setpoint_Values        0.002543
# Pressure_Data                    0.001851
# Real_Time_Performance_Index      0.001083
# Spare_Part_Usage                 0.000209
# Machine_Load_Percentage          0.000199
# Tool_Wear_Rate                  -0.000145
# Machine_Utilization_Rate        -0.000373
# Quality_Control_Test_Results    -0.000543
# Maintenance_Logs                -0.000591
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_target.index, y=correlation_with_target.values, palette='viridis')
plt.xticks(rotation=90)
plt.title(f'Correlation of Features with Fault_Diagnosis')
plt.xlabel('Features')
plt.ylabel('Correlation Coefficient')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-f290ee725b30>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_with_target.index, y=correlation_with_target.values, palette='viridis')

# %%
columns_to_drop = [
    'Tool_Wear_Rate', 'Machine_Utilization_Rate', 'Quality_Control_Test_Results',
    'Maintenance_Logs', 'Motor_Speed', 'Torque_Data', 'Machine_Start_Stop_Events',
    'Humidity_Levels', 'Failure_Mode_Indicators', 'Temperature_Readings',
    'Component_Degradation_Index', 'Idle_Time', 'Cycle_Time_Per_Operation',
    'Operator_Shift_Data', 'Air_Quality_Index',
    'Downtime_Incidents', 'Production_Rate', 'Repair_Logs', 'Datetime','Machine_Health_Index'
]

# %%
data = dataset.drop(columns=columns_to_drop)

# %%
data.head()
# Out:
#    Vibration_Level  Pressure_Data  Acoustic_Signals  Energy_Consumption  \
# 0         0.336129      15.346143         42.709897            1.994422
# 1         0.441680      19.648924         56.146535            7.086933
# 2         0.349080      10.466149         80.487979            8.155945
# 3         0.507108      32.012730         63.602072            0.974947
# 4         1.402247      22.620923         47.574150            1.401210
#
#    Machine_Load_Percentage  Ambient_Temperature   Humidity  \
# 0                59.016225            18.346641  10.120674
# 1                61.611488            40.000000  40.192417
# 2                78.768650             9.948006  50.411194
# 3                72.463480            25.603917  59.506915
# 4                68.816389            30.975052  30.847874
#
#    Previous_Fault_Occurrences  Predictive_Maintenance_Scores  \
# 0                           1                      18.707307
# ...

# %%
data.columns
# Out:
# Index(['Vibration_Level', 'Pressure_Data', 'Acoustic_Signals',
#        'Energy_Consumption', 'Machine_Load_Percentage', 'Ambient_Temperature',
#        'Humidity', 'Previous_Fault_Occurrences',
#        'Predictive_Maintenance_Scores', 'Real_Time_Performance_Index',
#        'Fault_Trigger_Timestamps', 'Controller_Setpoints',
#        'Actual_vs_Setpoint_Values', 'Alarm_Trigger_Data', 'Spare_Part_Usage',
#        'Anomaly_Scores', 'Fault_Probability', 'Fault_Diagnosis'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43825 entries, 0 to 43824
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Vibration_Level                43825 non-null  float64
#  1   Pressure_Data                  43825 non-null  float64
#  2   Acoustic_Signals               43825 non-null  float64
#  3   Energy_Consumption             43825 non-null  float64
#  4   Machine_Load_Percentage        43825 non-null  float64
#  5   Ambient_Temperature            43825 non-null  float64
#  6   Humidity                       43825 non-null  float64
#  7   Previous_Fault_Occurrences     43825 non-null  int64
#  8   Predictive_Maintenance_Scores  43825 non-null  float64
#  9   Real_Time_Performance_Index    43825 non-null  float64
#  10  Fault_Trigger_Timestamps       43825 non-null  int64
#  11  Controller_Setpoints           43825 non-null  float64
# ...

# %% [markdown]
# ## **Data Normalization**
#
# ---

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = data.drop('Fault_Diagnosis', axis=1)
y = data['Fault_Diagnosis']

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.32635389, -0.82633686, -0.47523828, ...,  1.63701296,
#          0.96493335, -0.27095238],
#        [-0.11515964, -0.55537583,  0.42311258, ...,  0.70565808,
#         -0.26832344, -1.44694674],
#        [-0.30043972, -1.13364703,  2.05054036, ..., -1.08583152,
#          0.86003216,  1.11253347],
#        ...,
#        [-0.49810526, -0.3323058 , -0.70687608, ...,  2.00107391,
#         -0.53183985, -1.01969198],
#        [ 0.49574727, -0.23828912,  0.04526906, ..., -0.15264093,
#         -0.87623381, -0.13220742],
#        [-0.76249234,  0.28893045,  0.09577251, ...,  0.96525598,
#         -1.12357801, -0.16312335]])

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 43820    2
# 43821    1
# 43822    0
# 43823    0
# 43824    0
# Name: Fault_Diagnosis, Length: 43825, dtype: int64

# %% [markdown]
# ## **Train Test Split**
#
# ---

# %%
from sklearn.model_selection import train_test_split

# %%
data['Fault_Diagnosis'].value_counts()
# Out:
# Fault_Diagnosis
# 0    30531
# 1     4470
# 2     4406
# 4     2229
# 3     2189
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# # **Implement Ensemble Models**
#
# ---

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## **Bagging**

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Decision Tree**

# %%
tree_model = DecisionTreeClassifier(random_state=42)

# %%
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
tree_pred = tree_model.predict(X_test)

# %%
print(classification_report(y_test, tree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.67      0.68      9159
#            1       0.10      0.11      0.11      1341
#            2       0.09      0.10      0.10      1322
#            3       0.04      0.04      0.04       657
#            4       0.04      0.05      0.05       669
#
#     accuracy                           0.49     13148
#    macro avg       0.20      0.19      0.19     13148
# weighted avg       0.51      0.49      0.50     13148

# %% [markdown]
# **Decision Tree with Bagging**

# %%
tree_bagging = BaggingClassifier(estimator=tree_model, n_estimators=10, random_state=42)

# %%
tree_bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(random_state=42),
#                   random_state=42)

# %%
tree_bagging_pred = tree_bagging.predict(X_test)

# %%
print(classification_report(y_test, tree_bagging_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.98      0.81      9159
#            1       0.16      0.02      0.03      1341
#            2       0.15      0.01      0.02      1322
#            3       0.11      0.00      0.01       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.69     13148
#    macro avg       0.22      0.20      0.17     13148
# weighted avg       0.52      0.69      0.57     13148

# %% [markdown]
# **Random Forest**

# %%
forest_model = RandomForestClassifier(random_state=42)

# %%
forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
forest_pred = forest_model.predict(X_test)

# %%
print(classification_report(y_test, forest_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# **Random Forest with Bagging**

# %%
forest_bagging = BaggingClassifier(estimator=forest_model, n_estimators=10, random_state=42)

# %%
forest_bagging.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=RandomForestClassifier(random_state=42),
#                   random_state=42)

# %%
forest_bagging_pred = forest_bagging.predict(X_test)

# %%
print(classification_report(y_test, forest_bagging_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# ### **Boosting**

# %%
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# **DecisionTreeClassifier or we can say AdaBoost**

# %% [markdown]
# Decision Tree Classifier as default weak learner for training purpose

# %%
model = AdaBoostClassifier(n_estimators=10, learning_rate=1)

# %%
model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(learning_rate=1, n_estimators=10)

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# **Using Different Base Learners SVC**

# %%
from sklearn.svm import SVC

# %%
svc = SVC(probability=True, kernel='linear')

# %%
svc.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
y_pred = svc.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.696607849102525

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# **SVC with AdaBoost**

# %%
svc_adaBoost = AdaBoostClassifier(estimator=svc, n_estimators=10, learning_rate=1)

# %%
svc_adaBoost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=SVC(kernel='linear', probability=True),
#                    learning_rate=1, n_estimators=10)

# %%
y_pred_adaboost = svc_adaBoost.predict(X_test)

# %%
print(classification_report(y_test, y_pred_adaboost, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# **Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(n_estimators=10, learning_rate=0.1, max_depth=5, random_state=101)

# %%
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=5, n_estimators=10, random_state=101)

# %%
y_pred_gbc = gbc.predict(X_test)

# %%
print(classification_report(y_test, y_pred_gbc, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# **XGBoost**

# %%
import xgboost as xgb
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier

# %%
xgb_clf = xgb.XGBClassifier(
    objective="multi:softmax",  # Multi-class classification
    num_class=5,               # Number of classes
    use_label_encoder=False,   # Suppress warnings for newer versions
    eval_metric="mlogloss",    # Evaluation metric for multi-class
    max_depth=3,               # Maximum depth of trees
    learning_rate=0.1,         # Learning rate
    n_estimators=100           # Number of trees
)

# %%
xgb_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [12:13:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_class=5, num_parallel_tree=None, ...)

# %%
y_pred = xgb_clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# **LightGBM**

# %%
import lightgbm as lgb
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Create a LightGBM dataset
train_data = lgb.Dataset(X_train, label=y_train)

# %%
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# %%
params = {
    'objective': 'multiclass',
    'num_class': 5,
    'metric': 'multi_logloss',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# %%
num_round = 100

# %%
bst = lgb.train(params, train_data, num_round, valid_sets=[test_data])
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012726 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3579
# [LightGBM] [Info] Number of data points in the train set: 30677, number of used features: 17
# [LightGBM] [Info] Start training from score -0.361432
# [LightGBM] [Info] Start training from score -2.282800
# [LightGBM] [Info] Start training from score -2.297286
# [LightGBM] [Info] Start training from score -2.996939
# [LightGBM] [Info] Start training from score -2.978827

# %%
y_pred = bst.predict(X_test, num_iteration=bst.best_iteration)

# %%
y_pred_max = np.argmax(y_pred, axis=1)

# %%
print(classification_report(y_test, y_pred_max, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# **CatBoost**

# %%
from catboost import CatBoostClassifier

# %%
# !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 5.7 MB/s eta 0:00:00
# ...

# %%
catboost_model = CatBoostClassifier(
    iterations=100,
    learning_rate=0.1,
    depth=6,
    verbose=0,
    random_seed=42
)

# %%
catboost_model.fit(X_train, y_train)

# %%
y_pred_cat = catboost_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred_cat, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148

# %% [markdown]
# ## **Stacking**

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
base_models = [
    ('DecisionTree', DecisionTreeClassifier(random_state=42)),
    ('RandomForest', RandomForestClassifier(random_state=42, n_estimators=100)),
    ('SVM', SVC(probability=True, random_state=42)),
    ('KNN', KNeighborsClassifier(n_neighbors=5))
]

# %%
# Meta model
meta_model = LogisticRegression(random_state=42)

# %%
n_splits = 5

# %%
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# %%
meta_features = np.zeros((X_train.shape[0], len(base_models)))

# %% [markdown]
# Train base models using cross-validation and generate meta features

# %%
for i, (name, model) in enumerate(base_models):
    meta_feature_fold = np.zeros((X_train.shape[0],))
    for train_idx, valid_idx in skf.split(X_train, y_train):
        X_fold_train, X_fold_valid = X_train[train_idx], X_train[valid_idx]
        y_fold_train, y_fold_valid = y_train.to_numpy()[train_idx], y_train.to_numpy()[valid_idx]

        model.fit(X_fold_train, y_fold_train)
        meta_feature_fold[valid_idx] = model.predict(X_fold_valid)

    meta_features[:, i] = meta_feature_fold

# %% [markdown]
# ## Voting
#
# ---

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
log_clf = LogisticRegression(random_state=42)
svc_clf = SVC(probability=True, random_state=42)
dt_clf = DecisionTreeClassifier(random_state=42)
knn_clf = KNeighborsClassifier()
rf_clf = RandomForestClassifier(random_state=42)

# %%
voting_clf = VotingClassifier(
    estimators=[
        ('log_reg', log_clf),
        ('svc', svc_clf),
        ('dt', dt_clf),
        ('knn', knn_clf),
        ('rf', rf_clf)
    ],
    voting='soft'
)

# %%
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('log_reg', LogisticRegression(random_state=42)),
#                              ('svc', SVC(probability=True, random_state=42)),
#                              ('dt', DecisionTreeClassifier(random_state=42)),
#                              ('knn', KNeighborsClassifier()),
#                              ('rf', RandomForestClassifier(random_state=42))],
#                  voting='soft')

# %%
for clf_name, clf in voting_clf.named_estimators_.items():
  clf.fit(X_train, y_train)
  y_pred = clf.predict(X_test)
  print(f"{clf_name} Accuracy: {accuracy_score(y_test, y_pred):.2f}")
# Out:
# log_reg Accuracy: 0.70
# svc Accuracy: 0.70
# dt Accuracy: 0.49
# knn Accuracy: 0.67
# rf Accuracy: 0.70

# %%
y_pred_voting = voting_clf.predict(X_test)
print(f"Voting Classifier Accuracy: {accuracy_score(y_test,y_pred_voting):.2f}")
# Out:
# Voting Classifier Accuracy: 0.70

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_voting,zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82      9159
#            1       0.00      0.00      0.00      1341
#            2       0.00      0.00      0.00      1322
#            3       0.00      0.00      0.00       657
#            4       0.00      0.00      0.00       669
#
#     accuracy                           0.70     13148
#    macro avg       0.14      0.20      0.16     13148
# weighted avg       0.49      0.70      0.57     13148
